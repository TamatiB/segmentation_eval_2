# %% [markdown]
# # Getting Pixel Fetaures from an Image

# %% [markdown]
# Note that cv2 cannot open multiple pages of tiff but pil can

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline

# %%
# okay so this crop method works
im = Image.open('Images/Substack2000.jpg')
croppo = im.crop((0, 30, frame.shape[1], frame.shape[0]-30))
imshow(np.asarray(pil_im))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ffde973e7039> in <module>()
#       2 im = Image.open('Images/Substack2000.jpg')
#       3 croppo = im.crop((0, 30, frame.shape[1], frame.shape[0]-30))
# ----> 4 imshow(croppo.show())
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3020                         filternorm=filternorm, filterrad=filterrad,
#    3021                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3022                         **kwargs)
#    3023     finally:
#    3024         ax.hold(washold)
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %% [markdown]
# From here this code is just snippet rubbish pretty much

# %%
tiff = Image.open('sample.tif')
try:
    while 1:
        # Convert PIL image to OpenCV
        image = cv.CreateImageHeader(tiff.size, cv.IPL_DEPTH_8U, 1)
        cv.SetData(image, tiff.tostring()) # It's "tostring" and not "toString()"!
        # Do whatever you're going to do with OpenCV data
        tiff.seek(tiff.tell()+1)
except EOFError:
    pass

# %%
from skimage import io
im = io.imread('Images/substack500.tif')
print (im.shape)
# Out:
# (500, 260, 348)

# %%
#if you want to show one image of the stack
imshow(np.asarray(im[2]))

# %%
frame = np.asarray(im[2])
frame.shape
# Out:
# (260, 348)

# %%
import cv2
import numpy as np
img = cv2.imread('Images/Substack2000.jpg')
#img = cv2.LoadImage("Images/substack500.tif",CV_LOAD_IMAGE_COLOR)
#type(img)
# Out:
# numpy.ndarray

# %%
# okay and then here I want to be able to crop an image using bounding box data and tiff stacks. 
# and then I can probably also 

crop_img = img[100:300,100:300].copy() # Crop from x, y, w, h -> 100, 200, 300, 400
# NOTE: its img[y: y + h, x: x + w] and *not* img[x: x + w, y: y + h]
cv2.imshow('image',img)
cv2.waitkey(0)
cv2.destroyAllWindows()
